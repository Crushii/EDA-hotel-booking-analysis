# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA Hotel Booking Analysis
# ##### **Contribution**    - Individual

# %% [markdown]
# Here’s a concise summary of my analysis on the hotel booking dataset:
#
# Summary of Hotel Booking Analysis
#
#
# Data Overview
#
#
# Dataset: Contains (119,390) rows and(32) columns, with a mix of float64, int64, and object data types.
#
#
# Missing Values:
#
#
# children: 4 missing values,
# country: 452 missing values,
# agent: 12,193 missing values,
# company: 82,137 missing value
#
# Duplicates: The dataset has 31,994 duplicate entries.
#
#
# Key Objectives
#
#
# Seasonality: Identify peak and off-peak booking periods.
#     Lead Time: Analyze how far in advance guests book.
#     Length of Stay: Understand typical guest stay durations:.
#    Cancellation Rates: Determine the proportion of bookings canceled.
#    Average Daily Rate (ADR): Understand pricing trends and revenue performance.
#    Guest Origin: Identify guest countries/regions.
#    Room Type Preferences: Analyze room type reservations.
#    Market Segments: Understand different market segment behaviors.
#
#
# Key Findings
#
#
# Cancellation Rates:
# City hotels have a higher percentage of booking cancellations, with 27.5% of
# bookings canceled overall.
# ADR and Stay Length:
# The Average Daily Rate (ADR) is relatively stable for stays longer than 1 day but decreases slightly beyond 6 days.
# ADR and Total People:
# ADR increases with the total number of guests, indicating direct proportionality.
# Retention Rate:
# Only 3.9% of guests were repeat visitors, suggesting a low retention rate.
# Booking Channels:
# 79.1% of bookings were made through travel agents or tour operators.
# Meal Preferences:
# BB (Bed & Breakfast) is the most preferred meal option.
# Guest Origin:
# A significant number of guests (over 25,000) are from Portugal.
# Peak Booking Months:
# Highest booking activity occurs in July and August.
# Lead Time:
# Resort hotels show a higher average lead time for bookings.
#
#
#
# Conclusions
# City hotels are the preferred choice among guests, as evidenced by the higher booking numbers and ADR compared to resort hotels.
# The reliance on travel agents highlights an opportunity for hotels to improve direct booking strategies.
# Optimal stay duration for both hotel types tends to be less than 7 days, typically around a week.
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/rough-ster/EDA-hotel-booking-analysis/blob/main/final_EDA_hotel_booking.ipynb

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Seasonality: Identify peak and off-peak booking periods throughout the year.
#
# Lead Time: Analyze how far in advance guests book their stays.
#
# Length of Stay: Understand the typical duration of guest stays.
#
# Cancellation Rates: Determine the proportion of bookings that are canceled.
#
# Average Daily Rate (ADR): Calculate the ADR to understand pricing trends and revenue performance.
#
# Guest Origin: Identify the countries or regions guests are coming from.
#
# Room Type Preferences: Analyze which room types are most frequently reserved and assigned.
#
# Market Segments: Understand different market segments (e.g., business, leisure) and their booking behaviors.

# %% [markdown]
# # **General Guidelines** : -

# %%
# Well-structured, formatted, and commented code is required.

# Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.

# The additional credits will have advantages over other students during Star Student selection.

#     [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#               without a single error logged. ]
# Each and every logic should have proper comments.

# You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.

# # Chart visualization code
# Why did you pick the specific chart?
# What is/are the insight(s) found from the chart?
# Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.
# You have to create at least 20 logical & meaningful charts having important insights.
# [ Hints : - Do the Vizualization in a structured way while following "UBM" Rule.

# U - Univariate Analysis,

# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)

# M - Multivariate Analysis ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
url = 'https://github.com/rough-ster/EDA-hotel-booking-analysis/blob/main/Hotel%20Bookings.csv?raw=true'
df_hotel_booking = pd.read_csv(url)

df_hotel_booking.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset First View

# %%
df_hotel_booking.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df_hotel_booking.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df_hotel_booking.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df_hotel_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df_hotel_booking.duplicated().sum()
# Out:
# 31994

# %%
# Drop Duplicates
df_hotel_booking.drop_duplicates(inplace = True)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df_hotel_booking.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(25, 10))
sns.heatmap(df_hotel_booking.isnull())
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# So we Have Null values in columns- Company, agent, Country,children.
#  company and agent  fill the Missing values with 0
# for country I will fill Missing values with object 'Others'. ( assuming while collecting data ,country name was not available so user selected the 'Others' option.)
# AS the count of missing values in Children Column is only 4, so we can replace with 0 considering no childrens.

# %%
(df_hotel_booking['agent'] == 0.0).sum() #checking for agent 0.0 type
# Out:
# 0

# %%
df_hotel_booking['agent'].fillna(0 , inplace=True) #replacing null agent with  0.0 type , meaning without any agent

# %%
(df_hotel_booking['company'] == 0.0).sum()  #checking for company 0.0 type
# Out:
# 0

# %%
df_hotel_booking['company'].fillna(0 , inplace=True)   #replacing null company with 0.0 type, meaning without any company

# %%
df_hotel_booking['country'].fillna('Others' , inplace=True) #others country ,may be because of not listed among the option

# %%
df_hotel_booking['children'].fillna(0 , inplace=True) #children =0

# %%
# Checking if all null values are removed
df_hotel_booking.isnull().sum().sort_values(ascending = False)[:5]
# Out:
# hotel                          0
# is_canceled                    0
# reservation_status             0
# total_of_special_requests      0
# required_car_parking_spaces    0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ### Data Description:
#
# 1. **hotel** : *Hotel(H1 = Resort Hotel , H2= City Hotel)*
#
# 2. **is_canceled** : *Value indicating if the booking was canceled (1) or not (0)*
#
# 3. **lead_time** :* Number of days that elapsed between the entering date of the booking into the PMS(Hotel Property Management System) and the arrival date*
#
# 4. **arrival_date_year** : *Year of arrival date*
#
# 5. **arrival_date_month** : *Month of arrival date*
#
# 6. **arrival_date_week_number** : *Week number of year for arrival date*
#
# 7. **arrival_date_day_of_month** : *Day of arrival date*
#
# 8. **stays_in_weekend_nights** : *Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel*
#
# 9. **stays_in_week_nights** : *Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel*
#
# 10. **adults** : *Number of adults*
#
# 11. **children** : *Number of children*
#
# 12. **babies** : *Number of babies*
#
# 13. **meal** : *kind of meal opted for*
#
# 14. **country** : *Country of customer.`*
#
# 15. **market_segment** : *Market segment designation.*
#
# 16. **distribution_channel** : *How customer accessed the stay*
#
# 17. **is_repeated_guest** : *Value indicating if the booking name was from a repeated guest (1) or not (0)*
#
# 18. **previous_cancellations** : *Number of previous bookings that were cancelled by the customer prior to the current booking*
#
# 19. **previous_bookings** : *count of previous bookings*
#
# 20. **reserved_room_type** : *Code of room type reserved.*
#
# 21. **assigned_room_type** : *Code for the type of room assigned.*
#
# 22. **booking_changes** : *Number of changes made to the booking *
#
# 23. **deposit_type** : *Indication if the customer made a deposit to guarantee the booking.*
#
# 24. **agent** : *ID of the travel agency that made the booking*
#
# 25. **company** : *ID of the company that made the booking.*
#
# 26. **days_in_waiting_list** : *Number of days the booking was in the waiting list before it was confirmed to the customer*
#
# 27. **customer_type** : *Type of booking*
#
#
# 28. **required_car_parking_spaces** : *car parking spaces required *
#
# 29. **total_of_special_requests** :* Number of special requests made by the customer*
#
# 30. **reservation_status** : *Reservation last status, assuming one of three categories*
# * Canceled – booking was canceled by the customer
# * Check-Out – customer has checked in but already departed
# * No-Show – customer did not check-in and did inform the hotel of the reason why
#
#
#
#
#
# 31. **reservation_status_date** : *Date at which the last status was set*

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df_hotel_booking.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df_hotel_booking.describe(include='all')
# Out:
#              hotel   is_canceled     lead_time  arrival_date_year  \
# count        87396  87396.000000  87396.000000       87396.000000
# unique           2           NaN           NaN                NaN
# top     City Hotel           NaN           NaN                NaN
# freq         53428           NaN           NaN                NaN
# mean           NaN      0.274898     79.891368        2016.210296
# std            NaN      0.446466     86.052325           0.686102
# min            NaN      0.000000      0.000000        2015.000000
# 25%            NaN      0.000000     11.000000        2016.000000
# 50%            NaN      0.000000     49.000000        2016.000000
# 75%            NaN      1.000000    125.000000        2017.000000
# max            NaN      1.000000    737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count               87396              87396.000000
# unique                 12                       NaN
# ...

# %% [markdown]
# ### Variables Description

# %%
#creating copy of dataframe

df= df_hotel_booking.copy()

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Checking the unique values in categorical columns.

# Drop the specified columns
df_filtered = df.drop(columns=['reservation_status_date', 'country', 'arrival_date_month'])

# Identify the numerical columns
numerical_cols = df_filtered.corr(numeric_only = True).columns

# Identify the categorical columns
categorical_cols = list(set(df_filtered.columns) - set(numerical_cols))

# Print the categorical columns
print(categorical_cols)

for col in categorical_cols:
  print(f'Unique values in column {col} are:, {df[col].unique()}')
# Out:
# ['deposit_type', 'customer_type', 'meal', 'distribution_channel', 'reserved_room_type', 'reservation_status', 'market_segment', 'assigned_room_type', 'hotel']
# Unique values in column deposit_type are:, ['No Deposit' 'Refundable' 'Non Refund']
# Unique values in column customer_type are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in column meal are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in column distribution_channel are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# Unique values in column reserved_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']
# Unique values in column reservation_status are:, ['Check-Out' 'Canceled' 'No-Show']
# Unique values in column market_segment are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in column assigned_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']
# ...

# %%
mismatched_count = df[df['reserved_room_type'] != df['assigned_room_type']].count()

# Calculate the total number of rows
total_count = df.count()

# Calculate the percentage of mismatched room types
percentage_mismatched = (mismatched_count / total_count) * 100

# Print the result
print(percentage_mismatched)
# Out:
# hotel                             14.999542
# is_canceled                       14.999542
# lead_time                         14.999542
# arrival_date_year                 14.999542
# arrival_date_month                14.999542
# arrival_date_week_number          14.999542
# arrival_date_day_of_month         14.999542
# stays_in_weekend_nights           14.999542
# stays_in_week_nights              14.999542
# adults                            14.999542
# children                          14.999542
# babies                            14.999542
# meal                              14.999542
# country                           14.999542
# market_segment                    14.999542
# distribution_channel              14.999542
# is_repeated_guest                 14.999542
# previous_cancellations            14.999542
# previous_bookings_not_canceled    14.999542
# reserved_room_type                14.999542
# assigned_room_type                14.999542
# ...

# %% [markdown]
# 14.89 % people did not get the room they booked for

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# lets add some new columns

df['total_people'] = df['adults'] + df['babies'] + df['children']
df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# %%
# Converting datatype of columns 'children', 'company' and 'agent' from float to int.
df[['children', 'company', 'agent']] = df[['children', 'company', 'agent']].astype('int64')

# %%
df[df['total_people']==0].shape #checking if total people column is having 0 people
# Out:
# (166, 34)

# %%
df.drop(df[df['total_people'] == 0].index, inplace = True) #dropping the rows where total people is 0

# %% [markdown]
# ---

# %%
Resort_cancelled = df[(df['hotel']=='Resort Hotel') & (df['is_canceled'] == 1)].shape[0]
Resort_hotels = df[df['hotel'] == 'Resort Hotel'].shape[0]
Resort_cancelled_percentage = Resort_cancelled / Resort_hotels * 100
Resort_cancelled_percentage
# Out:
# 23.483331370008244

# %% [markdown]
# 23.48 % of people booking a resort hotel cancel  the booking

# %%
city_cancelled = df[(df['hotel']=='City Hotel') & (df['is_canceled'] == 1)].shape[0]
city_hotels = df[df['hotel'] == 'City Hotel'].shape[0]
city_cancelled_percentage = city_cancelled / city_hotels * 100
city_cancelled_percentage
# Out:
# 30.099110260164437

# %% [markdown]
# 30.09 % of people booking a city hotel cancel  the booking
#
# that suggest city hotel are more prone to cancellaation than resort hotel

# %% [markdown]
# ---

# %%
# changing datatype of column 'reservation_status_date' to date data_type.
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

# %%
# Checking the final rows and columns
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df_resort_waiting_bookings = df[(df['hotel'] == 'Resort Hotel') & (df['days_in_waiting_list'] != 0)]

df_resort_waiting_bookings.shape[0]

Total_resort_bookings = df[df['hotel'] == 'Resort Hotel'].shape[0]

resort_waiting_percentage = df_resort_waiting_bookings.shape[0] / Total_resort_bookings * 100
resort_waiting_percentage
# Out:
# 0.41229826834727296

# %%
df_city_waiting_bookings = df[(df['hotel'] == 'City Hotel') & (df['days_in_waiting_list'] != 0)]

df_city_waiting_bookings.shape[0]

Total_city_bookings = df[df['hotel'] == 'City Hotel'].shape[0]

city_waiting_percentage = (df_city_waiting_bookings.shape[0] / Total_city_bookings) * 100
city_waiting_percentage
# Out:
# 1.3421181063933627

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# Lets first find the correlation between the numerical data.

# %%
num_df = df[['lead_time','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_stay','total_people']]

# %% [markdown]
# we are using heatmap to find correlation

# %%
#correlation matrix
corrmat = num_df.corr()
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(corrmat,annot = True,fmt='.2f', annot_kws={'size': 10 ,"color": "green"},   square=True);

# %% [markdown]
# Total stay length and lead time have slight correlation.
# This  means that for longer hotel stays people generally plan little before the the actual arrival.
#
# Average daily rate is correlated with total people

# %% [markdown]
# ---

# %% [markdown]
# 1) Which type of hotel is mostly prefered by the guests?

# %%
# Visualizsing the by pie chart.
df['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%',  figsize=(10,8),fontsize=20)
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %% [markdown]
# Most preffered hotel among is City Hotel ,
#
# Resort hotel has less bookings than City hotels

# %% [markdown]
# ---

# %% [markdown]
# Lets visualize number of non-zero bookings by each agent

# %%
d1 = pd.DataFrame(df['agent'].value_counts()).reset_index()

d1 = d1[:10]

d1.drop(d1[d1['agent']==0].index, inplace=True)
sns.barplot(x='agent', y='count', data=d1 ,order = d1.sort_values('count', ascending = False).agent)
plt.ylabel('Number of Bookings')
plt.title(" Bookings Made by the agent")
plt.show()

# %% [markdown]
# Agent 9 has significantlly more number of bookings than rest of the agents

# %% [markdown]
# ------

# %% [markdown]
# What is the pecentage of cancellation?

# %%
df['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', figsize=(10,8),fontsize=20)
plt.title("Cancellation(1) and non Cancellation(0)")
# Out:
# Text(0.5, 1.0, 'Cancellation(1) and non Cancellation(0)')

# %% [markdown]
# 27.5 % of the bookings were cancelled.

# %%
# Calculate the cancellation rate by 'deposit_type'
cancellation_by_deposit_type = df.groupby('deposit_type')['is_canceled'].mean() * 100

# Print the cancellation rates
print("Cancellation Rate by Deposit Type (%):")
print(cancellation_by_deposit_type)

plt.figure(figsize=(8, 5))
cancellation_by_deposit_type.plot(kind='bar', color='skyblue')

# Adding labels and title
plt.title('Cancellation Rate by Deposit Type', fontsize=14)
plt.xlabel('Deposit Type', fontsize=12)
plt.ylabel('Cancellation Rate (%)', fontsize=12)
plt.xticks(rotation=0)  # Keep the x-axis labels horizontal
plt.grid(axis='y', linestyle='--', alpha=0.7)
# Out:
# Cancellation Rate by Deposit Type (%):
# deposit_type
# No Deposit    26.717779
# Non Refund    94.701349
# Refundable    24.299065
# Name: is_canceled, dtype: float64

# %% [markdown]
# The cancellation rate for non-refundable bookings is extremely high (almost 95%). This could indicate that these "cancellations" are actually customers who didn't show up, but since the booking is non-refundable, the system marks them as canceled.

# %% [markdown]
# ---

# %%
df['is_repeated_guest'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', figsize=(10,8),fontsize=20)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# only 4 % of guest have revisited the hotels
#
# all other guestes are new to the hotels

# %% [markdown]
# ---

# %% [markdown]
# Which meal type is most preffered meal of customers?

# %%
plt.figure( figsize=(10, 8))

sns.countplot(x = df['meal'])
plt.show()

# %% [markdown]
#  BB - (Bed and Breakfast)
#
#  HB- (Half Board)
#
#  FB- (Full Board)
#
#  SC- (Self Catering)

# %% [markdown]
# Most preferred meal type is BB (Bed and breakfast)

# %% [markdown]
# ---

# %% [markdown]
# From which country the most guests are coming?

# %%
# Counting the guests from various countries.
country_df=df['country'].value_counts().reset_index()[:10]

# Visualizing by  plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_df['country'],y=country_df['count'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=20)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# Most of the guests are coming from portugal i.e more than 25000 guests are from portugal

# %% [markdown]
# ---

# %% [markdown]
# Which is the most preferred room type by the customers?

# %%
#set plotsize
plt.figure(figsize=(18,8))

#plotting
sns.countplot(x=df['assigned_room_type'],order=df['assigned_room_type'].value_counts().index)
#  set xlabel for the plot
plt.xlabel('Room Type')
# set y label for the plot
plt.ylabel('Count of Room Type')
#set title for the plot
plt.title("Most preferred Room type")
# Out:
# Text(0.5, 1.0, 'Most preferred Room type')

# %% [markdown]
# Room Type A is mostly Preffered

# %% [markdown]
# ---

# %% [markdown]
# In which month most of the bookings happened?

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df=df.groupby(['arrival_date_month'])['hotel'].count().reset_index()

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

bookings_by_months_df['arrival_date_month'] = pd.Categorical(bookings_by_months_df['arrival_date_month'], categories=month_order, ordered=True)


# bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')


# set plot size
plt.figure(figsize=(20,8))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x='arrival_date_month',y='hotel' ,data=bookings_by_months_df)#hue=bookings_by_months_df['hotel'])

# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# bookings observed in june, july, august months are higher than rest of months
#
#
# These months fall into the high tourist season in many parts of the world, especially in popular holiday destinations. Warmer weather encourages outdoor activities, making it an ideal time for travel.

# %%
Resort_hotels_booked = df[(df['hotel'] == 'Resort Hotel')]
# bookings_by_months_resort_df=Resort_hotels_booked.groupby(['arrival_date_month'])
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

Resort_hotels_booked['arrival_date_month'] = pd.Categorical(Resort_hotels_booked['arrival_date_month'], categories=month_order, ordered=True)

bookings_by_months_resort_df = Resort_hotels_booked.groupby(['arrival_date_month'])['hotel'].count().reset_index()





City_hotels_booked = df[(df['hotel'] == 'City Hotel')]
# bookings_by_months_resort_df=Resort_hotels_booked.groupby(['arrival_date_month'])
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

City_hotels_booked['arrival_date_month'] = pd.Categorical(City_hotels_booked['arrival_date_month'], categories=month_order, ordered=True)

bookings_by_months_City_df = City_hotels_booked.groupby(['arrival_date_month'])['hotel'].count().reset_index()






# set plot size
fig , ax = plt.subplots(nrows=2, ncols=1 ,figsize=(20,8))




# Line plot for Resort Hotel bookings
sns.lineplot(x='arrival_date_month', y='hotel', data=bookings_by_months_resort_df, ax=ax[0])
ax[0].set_title('Resort Hotel Bookings by Month')
ax[0].set_ylabel('Booking Count')

plt.subplots_adjust(hspace=0.5)

# Line plot for City Hotel bookings
sns.lineplot(x='arrival_date_month', y='hotel', data=bookings_by_months_City_df, ax=ax[1])
ax[1].set_title('City Hotel Bookings by Month')
ax[1].set_ylabel('number of bookin')
# Out:
# <ipython-input-46-f34f0900d5b1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Resort_hotels_booked['arrival_date_month'] = pd.Categorical(Resort_hotels_booked['arrival_date_month'], categories=month_order, ordered=True)
# <ipython-input-46-f34f0900d5b1>:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bookings_by_months_resort_df = Resort_hotels_booked.groupby(['arrival_date_month'])['hotel'].count().reset_index()
# <ipython-input-46-f34f0900d5b1>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# same trend of booking is observed in city hotel as well as resort hotel must be because of summer vacations

# %% [markdown]
# ---

# %% [markdown]
# Lets visualise boooking trend by booking channels used for the bookings

# %%
labels=df['distribution_channel'].value_counts().index.tolist()

# creating new df of distribution channel
distribution_channel_df=df['distribution_channel'].value_counts().reset_index()
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/df.shape[0],1)

#Creating list of percentage
sizes=distribution_channel_df['percentage'].values.tolist()


df['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], shadow=False, figsize=(15,8),fontsize=10,labels=labels)



labels = [f'{l}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.title('Distribution Channel used for Hotel Bookings ')

distribution_channel_df
# Out:
#   distribution_channel  count  percentage
# 0                TA/TO  69028        79.1
# 1               Direct  12954        14.9
# 2            Corporate   5062         5.8
# 3                  GDS    181         0.2
# 4            Undefined      5         0.0

# %% [markdown]
# 'TA/TO' is mostly(79.1%) used for booking hoetls.
#
# also 15% of bookings are done by direct booking method

# %% [markdown]
# ---

# %%
customer_type_counts = df['customer_type'].value_counts().reset_index()

customer_type_counts.columns = ['customer_type', 'value_counts']

# Create a bar plot to visualize the number of bookings per customer type
sns.barplot(x='customer_type', y='value_counts', data=customer_type_counts)
plt.title('Customer Type and their Booking Counts')
plt.xlabel('Customer Type')
plt.ylabel('Number of Bookings')
plt.show()

# %% [markdown]
# Bar chart is perfect to visualize counts of different categories

# %% [markdown]
# The majority of bookings are from "Transient" customers, with over 70,000 bookings, indicating that short-term individual stays make up a significant portion of the business.

# %% [markdown]
# ---

# %% [markdown]
# # Bivariate and Multivariate Analysis

# %%
sns.boxplot(x='hotel', y='total_stay', data=df)
plt.title('Length of Stay by Accommodation Type')
plt.show()

# %% [markdown]
# Resort Hotel is likely to have longer stay duration than city hotel

# %% [markdown]
# ---

# %% [markdown]
# ADR across the different month.

# %%
#groupby
bookings_by_months_df=df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
#create month list
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# it will take the order of the month list in the df along with values
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
#sortting
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')


# set plot size and plot the line
plt.figure(figsize=(20,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# For Resrot hotel is ADR is high in the months June,July,August,september as compared to City Hotels.
#
# The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the avrage daily rate in this month is very low.

# %% [markdown]
# ----

# %% [markdown]
# Which Hotel type has the highest ADR?

# %%
grup_by_hotel=df.groupby('hotel')

#grouping by hotel adr
highest_adr=grup_by_hotel['adr'].mean().reset_index()

#set plot size
plt.figure(figsize=(10,8))

# set labels
plt.xlabel('Hotel type')
plt.ylabel('ADR')
plt.title("Avg ADR of each Hotel type")

#plot the graph
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'Avg ADR of each Hotel type'}, xlabel='Hotel type', ylabel='ADR'>

# %% [markdown]
# City hotel has the higher ADR

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# ADR across different  market segment

# %%
Grupby=df.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()
# set plot size and plto barchart
plt.figure(figsize=(18,6))
sns.barplot(x='market_segment',y='adr',hue='hotel',data=Grupby.sort_values(by='adr',ascending=False))
plt.title('Adr across market segment')
# Out:
# Text(0.5, 1.0, 'Adr across market segment')

# %% [markdown]
# Direct' and 'Online TA' are contributing the most in both types of hotels.
#
# Aviation segment should focus on increasing the bookings of 'City Hotel

# %% [markdown]
# ---

# %% [markdown]
# Which hotel has highest percentage of booking cancellation?

# %%
# booking canceled=1
# booking not canceled= 0

# creating new DataFrame where bookings are cancelled.
canceled_df=df[df['is_canceled']==1]

# Grouping by hotel
canceled_df=canceled_df.groupby('hotel').size().reset_index().rename(columns={0: "no_of_cancelled_bookings"})

# adding 'total booking column for calculating the percentage.
canceled_df['total_booikngs']=df.groupby('hotel').size().reset_index().rename(columns={0:"total_bookings"}).drop('hotel',axis=1)
canceled_df

#plotting the barchat
plt.figure(figsize=(10,8))
sns.barplot(x=canceled_df['hotel'],y=canceled_df['no_of_cancelled_bookings']*100/canceled_df['total_booikngs'])

#set labels
plt.xlabel('Hotel type')
plt.ylabel('Percentage(%)')
plt.title("Percentage of booking cancellation")
# Out:
# Text(0.5, 1.0, 'Percentage of booking cancellation')

# %% [markdown]
# City hotel has high percentage of booking cancellations

# %% [markdown]
# ---

# %% [markdown]
# Relationship between ADR and total stay.

# %%
# Groupby adr,total,stay,hotel,
adr_vs_stay = df.groupby(['total_stay', 'adr','hotel']).agg('count').reset_index()
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay.rename(columns={'is_canceled':'Number of stays'})
adr_vs_stay=adr_vs_stay[:18000]

#plot line chart
plt.figure(figsize=(16,8))
sns.lineplot(x='total_stay',y='adr',data=adr_vs_stay)
plt.xlim(1, 10)
plt.title('Relationship between adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between adr and total stay')

# %% [markdown]
# ADR is nearly same for stay of more than 1 day
# it decreases slightly as stay is more than 6 days

# %% [markdown]
# ---

# %% [markdown]
# ADR relationship with total number of people

# %%
plt.figure(figsize=(20,8))
df.drop(df[df['adr'] > 5000].index, inplace = True)

df2=df[df['total_people'] < 6]

sns.boxplot(x=df2['total_people'],y=df2['adr'])

# set lables
plt.title('ADR v/s Total Number of people')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# As the total number of people increases adr also increases.
# Thus adr and total people are directly proportional to each other.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# City hotels are the most preferred hotel type by the guests. We can say City hotel is the busier  hotel.
#
# 27.5 % bookings were got cancelled out of all the bookings.
#
# Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. Thus retention rate is low.
#
# Most of the customers (91.6%) do not require car parking spaces.
#
# 79.1 % bookings were made through TA/TO (travel agents/Tour operators).
#
# BB Bed & Breakfast is the most preferred  type of meal by the guests. 	Maximum
#
# number of guests were from Portugal, i.e. more than 25000 guests.
#
# Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
#
# highest number of bookings happen for july and august month
#
# Average lead time for resort hotel is high.
#
# Aviation segment should focus on increasing the bookings of 'City Hotel
#
# Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
